# %%
# !pip install git+https://github.com/tensorflow/docs
 
from IPython import display
 
import time
import glob
 
 
import numpy as np
import tensorflow as tf
# !pip install tensorflow-probability
import tensorflow_probability as tfp
import PIL
 
# to generate gifs
# !pip install imageio
import imageio
 
import matplotlib.pyplot as plt
import cv2
 
# !git clone https://github.com/VMrGamer/latent-space-investigation.git
import sys
sys.path.append('./latent-space-investigation/modules')
from the_program import the_program
# Out:
# ...
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-r6g81cpj
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-r6g81cpj
# ...
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.04fb5626d53bb4c8797f65e1d352bb1556ba10d72_-py3-none-any.whl size=154541 sha256=ffd655ba367edb6fd780da9b67f37aca8bca0247d31b17a72efb2f07fd04be51
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f4afiart/wheels/cc/c4/d8/5341e93b6376c5c929c49469fce21155eb69cef1a4da4ce32c
#   WARNING: Built wheel for tensorflow-docs is invalid: Metadata 1.2 mandates PEP 440 version, but '0.0.04fb5626d53bb4c8797f65e1d352bb1556ba10d72-' is not
# Failed to build tensorflow-docs
# ...
#     Running setup.py install for tensorflow-docs ... done
# ...

# %%
DATASET='fashion_mnist'
prog = the_program(DATASET).run()
# Out:
# Epoch: 10, Test set ELBO: -191.81039428710938, time elapse for current epoch: 8.441927194595337

# %%
def display_image(epoch_no):
    return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))
 
plt.imshow(display_image(prog.m_helper.epochs))
plt.axis('off')  # Display images
# Out:
# (-0.5, 287.5, 287.5, -0.5)

# %%
anim_file = 'cvae.gif'
 
with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('image*.png')
    filenames = sorted(filenames)
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)
    
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
prog.m_helper.plot_latent_images(20)
