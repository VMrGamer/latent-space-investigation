# %%
# !pip install git+https://github.com/tensorflow/docs

from IPython import display

import time
import glob


import numpy as np
import tensorflow as tf
# !pip install tensorflow-probability
import tensorflow_probability as tfp
import PIL

# to generate gifs
# !pip install imageio
import imageio

import matplotlib.pyplot as plt
import cv2

import sys
sys.path.append('../modules')

from the_program import the_program
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to c:\users\vmrga\appdata\local\temp\pip-req-build-dstkecz9
#   Resolved https://github.com/tensorflow/docs to commit e2abff4864c2895987c866a18db399991e0d7f50
# Requirement already satisfied: astor in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-docs===0.0.0e2abff4864c2895987c866a18db399991e0d7f50-) (0.8.1)
# Requirement already satisfied: absl-py in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-docs===0.0.0e2abff4864c2895987c866a18db399991e0d7f50-) (0.10.0)
# Requirement already satisfied: protobuf>=3.14 in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-docs===0.0.0e2abff4864c2895987c866a18db399991e0d7f50-) (3.17.3)
# Requirement already satisfied: pyyaml in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-docs===0.0.0e2abff4864c2895987c866a18db399991e0d7f50-) (5.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\vmrga\anaconda3\lib\site-packages (from protobuf>=3.14->tensorflow-docs===0.0.0e2abff4864c2895987c866a18db399991e0d7f50-) (1.15.0)
#   Running command git clone -q https://github.com/tensorflow/docs 'C:\Users\VMrGa\AppData\Local\Temp\pip-req-build-dstkecz9'
# Requirement already satisfied: tensorflow-probability in c:\users\vmrga\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: dm-tree in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.6)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (1.6.0)
# Requirement already satisfied: decorator in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (4.4.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (1.19.5)
# Requirement already satisfied: gast>=0.3.2 in c:\users\vmrga\anaconda3\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: imageio in c:\users\vmrga\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: pillow in c:\users\vmrga\anaconda3\lib\site-packages (from imageio) (8.0.1)
# Requirement already satisfied: numpy in c:\users\vmrga\anaconda3\lib\site-packages (from imageio) (1.19.5)

# %%
prog = the_program().run()
# Out:
# Epoch: 1, Test set ELBO: -178.56227111816406, time elapse for current epoch: 34.41209673881531

# %%
def display_image(epoch_no):
    return PIL.Image.open('./image_at_epoch_{:04d}.png'.format(epoch_no))

plt.imshow(display_image(prog.m_helper.epochs))
plt.axis('off')  # Display images
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3ab5871bf1b3> in <module>
#       2     return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))
#       3
# ----> 4 plt.imshow(display_image(prog.m_helper.epochs))
#       5 plt.axis('off')  # Display images
#
# <ipython-input-3-3ab5871bf1b3> in display_image(epoch_no)
#       1 def display_image(epoch_no):
# ----> 2     return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))
#       3
#       4 plt.imshow(display_image(prog.m_helper.epochs))
#       5 plt.axis('off')  # Display images
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image_at_epoch_0010.png'

# %%
anim_file = 'cvae.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('image*.png')
    filenames = sorted(filenames)
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)
    
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
prog.m_helper.plot_latent_images(20)
